# %%
# import os
# os.environ["HTTP_PROXY"] = "http://127.0.0.1:7890"
# os.environ["HTTPS_PROXY"] = "http://127.0.0.1:7890"

# %%
from datasets import load_dataset
ds = load_dataset("FortyAI/WuDao")
# Out:
# C:\Users\hhm18\miniconda3\envs\env_LLM\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# README.md:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# C:\Users\hhm18\miniconda3\envs\env_LLM\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\hhm18\.cache\huggingface\hub\datasets--FortyAI--WuDao. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...

# %%
# checkpoint = torch.load(".model/checkpoints/llm_experiment_3/final_model.pt", map_location="cuda")
# print(checkpoint.keys())

# %%
# 加载模型权重
# model.load_state_dict(checkpoint['model_state_dict'])
# best_val_loss = checkpoint['best_val_loss']
# config = checkpoint['config']

# %%
# import torch
# from transformers import AutoModelForCausalLM, AutoTokenizer

# model.eval()

# input_text = "中新网3月13日电《澳门日报》今日在头条刊发报道称"
# inputs = tokenizer(input_text, return_tensors="pt")

# # 获取输入的 token IDs
# input_ids = inputs["input_ids"]
# attention_mask = inputs['attention_mask']

# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# model.to(device)
# input_ids = input_ids.to(device)
# attention_mask = attention_mask.to(device)

# # 生成后续的 token
# generated_tokens = []
# num_tokens_to_generate = 20  # 生成的 token 数量
# with torch.no_grad():
#     for _ in range(num_tokens_to_generate):
#         outputs = model(input_ids)
#         logits = outputs["logits"][:, -1, :]  # 获取最后一个 token 的 logits
#         next_token = torch.argmax(logits, dim=-1).unsqueeze(0) # 贪心
#         input_ids = torch.cat([input_ids, next_token], dim=-1)
#         generated_tokens.append(next_token.item())
# # 将生成的 token 转换为文本
# generated_text = tokenizer.decode(generated_tokens, skip_special_tokens=True)

# print("Generated text:", generated_text)
